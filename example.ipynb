# %%
from model import Model
from matplotlib.pyplot import imshow

# %%
model = Model('./yolov8n_silu_coco.tflite', do_postprocessing=True, labels='./labels_coco.json')
img = 'https://media.istockphoto.com/id/537506462/photo/three-cats-laying-together-on-white.jpg?s=612x612&w=0&k=20&c=uLe3k5ojxp5RTQGwBQXV5Sj9UYT7kYdpSi_urcnIyRU='
res = model(img)
imshow(res.image_overlay)
# Out:
# 2023-08-08 20:41:37.904924: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-08 20:41:38.551289: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
print(res)
# Out:
# - bbox: [356.1879322548266, 60.80205694694746, 579.8867497843598, 293.2526392013783]
#   category_id: 15
#   label: cat
#   score: 0.9239747524261475
# - bbox: [46.00660266542491, 101.97304513018616, 252.33696885452628, 290.5742464104611]
#   category_id: 15
#   label: cat
#   score: 0.9229344129562378
# - bbox: [235.51038893593977, 90.0718817933705, 364.21456299804413, 279.5438906638474]
#   category_id: 15
#   label: cat
#   score: 0.8296515941619873
