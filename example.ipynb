# %%
from model import Model
from matplotlib.pyplot import imshow

# %%
# model = Model('./models/yolov8n_silu_float.tflite', labels='./labels_coco.json')
# model = Model('./models/yolov8n_original.onnx', do_bbox_decoding=False, labels='./labels_coco.json')
model = Model('./models/yolov8n_silu_quant.tflite', postprocessor_inputs=[0, 3, 4, 5, 1, 2], labels='./labels_coco.json')
img = 'https://media.istockphoto.com/id/537506462/photo/three-cats-laying-together-on-white.jpg?s=612x612&w=0&k=20&c=uLe3k5ojxp5RTQGwBQXV5Sj9UYT7kYdpSi_urcnIyRU='
res = model(img)
imshow(res.image_overlay)

# %%
print(res)
# Out:
# - bbox: [357.8020447941908, 59.21749727499537, 579.5961266142506, 293.41750826448197]
#   category_id: 15
#   label: cat
#   score: 0.9093707799911499
# - bbox: [45.37321435961735, 100.12746128241542, 252.7796903437311, 289.9057285382162]
#   category_id: 15
#   label: cat
#   score: 0.9093707799911499
# - bbox: [234.55613129774042, 89.7409827678589, 365.18348729631816, 276.9019635578211]
#   category_id: 15
#   label: cat
#   score: 0.7826365828514099
