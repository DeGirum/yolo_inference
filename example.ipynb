# %%
from model import Model
from matplotlib.pyplot import imshow

# %%
# model = Model('./models/yolov8n_silu_float.tflite', labels='./labels_coco.json')
# model = Model('./models/yolov8n_silu_float_6outs.onnx', labels='./labels_coco.json')
model = Model('./models/yolov8n_original.onnx', do_bbox_decoding=False, labels='./labels_coco.json')
# model = Model('./models/yolov8n_silu_quant.tflite', labels='./labels_coco.json')
img = 'https://media.istockphoto.com/id/537506462/photo/three-cats-laying-together-on-white.jpg?s=612x612&w=0&k=20&c=uLe3k5ojxp5RTQGwBQXV5Sj9UYT7kYdpSi_urcnIyRU='
res = model(img)
imshow(res.image_overlay)

# %%
print(res)
# Out:
# - bbox: [356.18793539123544, 60.802073585065386, 579.8867694631186, 293.25265612496605]
#   category_id: 15
#   label: cat
#   score: 0.9239750504493713
# - bbox: [46.006605249459426, 101.97303198907775, 252.33697340379877, 290.57424157391756]
#   category_id: 15
#   label: cat
#   score: 0.9229341745376587
# - bbox: [235.51037037556853, 90.0718871326244, 364.2145406387426, 279.543882426472]
#   category_id: 15
#   label: cat
#   score: 0.8296512365341187
