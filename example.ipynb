# %%
from model import Model
from matplotlib.pyplot import imshow

# %%
# model = Model('./ultralytics_models/yolov8n_silu_coco--576x576_quant_cpu_1out.tflite', do_bbox_decoding=False, labels='./labels_coco.json')
model = Model('./dg_models/yolov8n_silu_face--640x640_quant_cpu_6outs.tflite', labels='./dg_models/labels_face.json')
img = 'https://st4.depositphotos.com/3261171/20615/i/450/depositphotos_206157578-stock-photo-confident-smart-man-standing-near.jpg%22'
res = model(img)
imshow(res.image_overlay)

# %%
print(res)
# Out:
# - bbox: [45.5780825674924, 106.37278681230919, 253.25461185287622, 290.6605092316656]
#   category_id: 15
#   label: cat
#   score: 0.968760073184967
# - bbox: [357.13029462807026, 60.91704375507334, 578.7741555042151, 293.46795951443937]
#   category_id: 15
#   label: cat
#   score: 0.9610356092453003
# - bbox: [233.22865602530692, 90.31441962258259, 362.65697534371884, 275.4049644394363]
#   category_id: 15
#   label: cat
#   score: 0.9080075621604919
