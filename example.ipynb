# %%
from model import Model
from matplotlib.pyplot import imshow

# %%
model_path = './models/yolov8n_relu6_coco--576x576_quant_edgetpu_6outs.tflite'
labels_path = './label_files/labels_coco.json'
img = './images/demo_cat.jpg'

# %%
model = Model(model_path, labels=labels_path)
# Out:
# 2023-08-10 17:10:34.869954: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-10 17:10:34.911012: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-10 17:10:34.912461: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-10 17:10:35.530914: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# EdgeTPU delegate found!

# %%
res = model(img)
imshow(res.image_overlay)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
print(res)
# Out:
# - bbox: [323.84959794639144, 185.90507057087962, 1002.5341950812921, 1153.6286066831963]
#   category_id: 15
#   label: cat
#   score: 0.7983798980712891
